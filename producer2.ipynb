# %% [markdown]
# <a href="https://colab.research.google.com/github/kittipat7/DADS6005_Project/blob/main/producer2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#coindesk
# %%capture
# !pip install confluent_kafka
#!pip install -U coindesk

# %%
from confluent_kafka import Producer
import requests
import json
import time

# Set up the Kafka producer
p = Producer({'bootstrap.servers': 'ec2-13-229-46-113.ap-southeast-1.compute.amazonaws.com:9092'})

# Set the CryptoCompare API endpoint and any necessary headers or parameters
api_endpoint = "https://api.coindesk.com/v1/bpi/currentprice.json"

# Retrieve data from the CryptoCompare API in a loop
while True:
    # Make a request to the CryptoCompare API
    response = requests.get(api_endpoint)
    data = response.json()

    # Convert the data to a string and produce it to Kafka
    data_str = json.dumps(data)
    print(data_str)
    p.produce('btc1', data_str.encode('utf-8'))
    p.flush()
    time.sleep(60)
# Out:
# {"time": {"updated": "Jan 12, 2023 11:20:00 UTC", "updatedISO": "2023-01-12T11:20:00+00:00", "updateduk": "Jan 12, 2023 at 11:20 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,187.6348", "description": "United States Dollar", "rate_float": 18187.6348}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,197.4422", "description": "British Pound Sterling", "rate_float": 15197.4422}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,717.4117", "description": "Euro", "rate_float": 17717.4117}}}
# {"time": {"updated": "Jan 12, 2023 11:21:00 UTC", "updatedISO": "2023-01-12T11:21:00+00:00", "updateduk": "Jan 12, 2023 at 11:21 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,187.2663", "description": "United States Dollar", "rate_float": 18187.2663}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,197.1342", "description": "British Pound Sterling", "rate_float": 15197.1342}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,717.0527", "description": "Euro", "rate_float": 17717.0527}}}
# {"time": {"updated": "Jan 12, 2023 11:22:00 UTC", "updatedISO": "2023-01-12T11:22:00+00:00", "updateduk": "Jan 12, 2023 at 11:22 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,185.2614", "description": "United States Dollar", "rate_float": 18185.2614}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,195.4590", "description": "British Pound Sterling", "rate_float": 15195.459}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,715.0997", "description": "Euro", "rate_float": 17715.0997}}}
# {"time": {"updated": "Jan 12, 2023 11:23:00 UTC", "updatedISO": "2023-01-12T11:23:00+00:00", "updateduk": "Jan 12, 2023 at 11:23 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,181.2231", "description": "United States Dollar", "rate_float": 18181.2231}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,192.0846", "description": "British Pound Sterling", "rate_float": 15192.0846}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,711.1658", "description": "Euro", "rate_float": 17711.1658}}}
# {"time": {"updated": "Jan 12, 2023 11:24:00 UTC", "updatedISO": "2023-01-12T11:24:00+00:00", "updateduk": "Jan 12, 2023 at 11:24 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,176.5891", "description": "United States Dollar", "rate_float": 18176.5891}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,188.2124", "description": "British Pound Sterling", "rate_float": 15188.2124}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,706.6516", "description": "Euro", "rate_float": 17706.6516}}}
# {"time": {"updated": "Jan 12, 2023 11:25:00 UTC", "updatedISO": "2023-01-12T11:25:00+00:00", "updateduk": "Jan 12, 2023 at 11:25 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,179.4981", "description": "United States Dollar", "rate_float": 18179.4981}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,190.6432", "description": "British Pound Sterling", "rate_float": 15190.6432}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,709.4854", "description": "Euro", "rate_float": 17709.4854}}}
# {"time": {"updated": "Jan 12, 2023 11:26:00 UTC", "updatedISO": "2023-01-12T11:26:00+00:00", "updateduk": "Jan 12, 2023 at 11:26 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,181.8576", "description": "United States Dollar", "rate_float": 18181.8576}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,192.6148", "description": "British Pound Sterling", "rate_float": 15192.6148}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,711.7839", "description": "Euro", "rate_float": 17711.7839}}}
# {"time": {"updated": "Jan 12, 2023 11:27:00 UTC", "updatedISO": "2023-01-12T11:27:00+00:00", "updateduk": "Jan 12, 2023 at 11:27 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,177.5933", "description": "United States Dollar", "rate_float": 18177.5933}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,189.0515", "description": "British Pound Sterling", "rate_float": 15189.0515}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,707.6298", "description": "Euro", "rate_float": 17707.6298}}}
# {"time": {"updated": "Jan 12, 2023 11:28:00 UTC", "updatedISO": "2023-01-12T11:28:00+00:00", "updateduk": "Jan 12, 2023 at 11:28 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,177.3211", "description": "United States Dollar", "rate_float": 18177.3211}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,188.8241", "description": "British Pound Sterling", "rate_float": 15188.8241}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,707.3647", "description": "Euro", "rate_float": 17707.3647}}}
# {"time": {"updated": "Jan 12, 2023 11:29:00 UTC", "updatedISO": "2023-01-12T11:29:00+00:00", "updateduk": "Jan 12, 2023 at 11:29 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,172.1249", "description": "United States Dollar", "rate_float": 18172.1249}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,184.4821", "description": "British Pound Sterling", "rate_float": 15184.4821}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,702.3027", "description": "Euro", "rate_float": 17702.3027}}}
# {"time": {"updated": "Jan 12, 2023 11:30:00 UTC", "updatedISO": "2023-01-12T11:30:00+00:00", "updateduk": "Jan 12, 2023 at 11:30 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,170.7461", "description": "United States Dollar", "rate_float": 18170.7461}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,183.3300", "description": "British Pound Sterling", "rate_float": 15183.33}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,700.9596", "description": "Euro", "rate_float": 17700.9596}}}
# {"time": {"updated": "Jan 12, 2023 11:31:00 UTC", "updatedISO": "2023-01-12T11:31:00+00:00", "updateduk": "Jan 12, 2023 at 11:31 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,179.8299", "description": "United States Dollar", "rate_float": 18179.8299}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,190.9205", "description": "British Pound Sterling", "rate_float": 15190.9205}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,709.8086", "description": "Euro", "rate_float": 17709.8086}}}
# {"time": {"updated": "Jan 12, 2023 11:32:00 UTC", "updatedISO": "2023-01-12T11:32:00+00:00", "updateduk": "Jan 12, 2023 at 11:32 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,179.9908", "description": "United States Dollar", "rate_float": 18179.9908}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,191.0548", "description": "British Pound Sterling", "rate_float": 15191.0548}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,709.9653", "description": "Euro", "rate_float": 17709.9653}}}
# {"time": {"updated": "Jan 12, 2023 11:33:00 UTC", "updatedISO": "2023-01-12T11:33:00+00:00", "updateduk": "Jan 12, 2023 at 11:33 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,184.0594", "description": "United States Dollar", "rate_float": 18184.0594}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,194.4545", "description": "British Pound Sterling", "rate_float": 15194.4545}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,713.9287", "description": "Euro", "rate_float": 17713.9287}}}
# {"time": {"updated": "Jan 12, 2023 11:35:00 UTC", "updatedISO": "2023-01-12T11:35:00+00:00", "updateduk": "Jan 12, 2023 at 11:35 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,179.7894", "description": "United States Dollar", "rate_float": 18179.7894}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,190.8866", "description": "British Pound Sterling", "rate_float": 15190.8866}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,709.7692", "description": "Euro", "rate_float": 17709.7692}}}
# {"time": {"updated": "Jan 12, 2023 11:36:00 UTC", "updatedISO": "2023-01-12T11:36:00+00:00", "updateduk": "Jan 12, 2023 at 11:36 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,186.4227", "description": "United States Dollar", "rate_float": 18186.4227}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,196.4293", "description": "British Pound Sterling", "rate_float": 15196.4293}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,716.2309", "description": "Euro", "rate_float": 17716.2309}}}
# {"time": {"updated": "Jan 12, 2023 11:37:00 UTC", "updatedISO": "2023-01-12T11:37:00+00:00", "updateduk": "Jan 12, 2023 at 11:37 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,186.3124", "description": "United States Dollar", "rate_float": 18186.3124}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,196.3371", "description": "British Pound Sterling", "rate_float": 15196.3371}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,716.1235", "description": "Euro", "rate_float": 17716.1235}}}
# {"time": {"updated": "Jan 12, 2023 11:38:00 UTC", "updatedISO": "2023-01-12T11:38:00+00:00", "updateduk": "Jan 12, 2023 at 11:38 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,183.8295", "description": "United States Dollar", "rate_float": 18183.8295}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,194.2624", "description": "British Pound Sterling", "rate_float": 15194.2624}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,713.7047", "description": "Euro", "rate_float": 17713.7047}}}
# {"time": {"updated": "Jan 12, 2023 11:39:00 UTC", "updatedISO": "2023-01-12T11:39:00+00:00", "updateduk": "Jan 12, 2023 at 11:39 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,188.0452", "description": "United States Dollar", "rate_float": 18188.0452}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,197.7851", "description": "British Pound Sterling", "rate_float": 15197.7851}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,717.8115", "description": "Euro", "rate_float": 17717.8115}}}
# {"time": {"updated": "Jan 12, 2023 11:40:00 UTC", "updatedISO": "2023-01-12T11:40:00+00:00", "updateduk": "Jan 12, 2023 at 11:40 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,185.6518", "description": "United States Dollar", "rate_float": 18185.6518}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,195.7851", "description": "British Pound Sterling", "rate_float": 15195.7851}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,715.4799", "description": "Euro", "rate_float": 17715.4799}}}
# {"time": {"updated": "Jan 12, 2023 11:41:00 UTC", "updatedISO": "2023-01-12T11:41:00+00:00", "updateduk": "Jan 12, 2023 at 11:41 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,187.1364", "description": "United States Dollar", "rate_float": 18187.1364}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,197.0257", "description": "British Pound Sterling", "rate_float": 15197.0257}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,716.9261", "description": "Euro", "rate_float": 17716.9261}}}
# {"time": {"updated": "Jan 12, 2023 11:42:00 UTC", "updatedISO": "2023-01-12T11:42:00+00:00", "updateduk": "Jan 12, 2023 at 11:42 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,186.7751", "description": "United States Dollar", "rate_float": 18186.7751}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,196.7238", "description": "British Pound Sterling", "rate_float": 15196.7238}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,716.5742", "description": "Euro", "rate_float": 17716.5742}}}
# {"time": {"updated": "Jan 12, 2023 11:43:00 UTC", "updatedISO": "2023-01-12T11:43:00+00:00", "updateduk": "Jan 12, 2023 at 11:43 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,199.6542", "description": "United States Dollar", "rate_float": 18199.6542}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,207.4854", "description": "British Pound Sterling", "rate_float": 15207.4854}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,729.1203", "description": "Euro", "rate_float": 17729.1203}}}
# {"time": {"updated": "Jan 12, 2023 11:44:00 UTC", "updatedISO": "2023-01-12T11:44:00+00:00", "updateduk": "Jan 12, 2023 at 11:44 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,196.0083", "description": "United States Dollar", "rate_float": 18196.0083}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,204.4389", "description": "British Pound Sterling", "rate_float": 15204.4389}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,725.5687", "description": "Euro", "rate_float": 17725.5687}}}
# {"time": {"updated": "Jan 12, 2023 11:45:00 UTC", "updatedISO": "2023-01-12T11:45:00+00:00", "updateduk": "Jan 12, 2023 at 11:45 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,208.0041", "description": "United States Dollar", "rate_float": 18208.0041}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,214.4626", "description": "British Pound Sterling", "rate_float": 15214.4626}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,737.2544", "description": "Euro", "rate_float": 17737.2544}}}
# {"time": {"updated": "Jan 12, 2023 11:46:00 UTC", "updatedISO": "2023-01-12T11:46:00+00:00", "updateduk": "Jan 12, 2023 at 11:46 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,207.1769", "description": "United States Dollar", "rate_float": 18207.1769}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,213.7714", "description": "British Pound Sterling", "rate_float": 15213.7714}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,736.4486", "description": "Euro", "rate_float": 17736.4486}}}
# {"time": {"updated": "Jan 12, 2023 11:47:00 UTC", "updatedISO": "2023-01-12T11:47:00+00:00", "updateduk": "Jan 12, 2023 at 11:47 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,199.7623", "description": "United States Dollar", "rate_float": 18199.7623}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,207.5758", "description": "British Pound Sterling", "rate_float": 15207.5758}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,729.2256", "description": "Euro", "rate_float": 17729.2256}}}
# {"time": {"updated": "Jan 12, 2023 11:48:00 UTC", "updatedISO": "2023-01-12T11:48:00+00:00", "updateduk": "Jan 12, 2023 at 11:48 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,190.7960", "description": "United States Dollar", "rate_float": 18190.796}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,200.0836", "description": "British Pound Sterling", "rate_float": 15200.0836}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,720.4912", "description": "Euro", "rate_float": 17720.4912}}}
# {"time": {"updated": "Jan 12, 2023 11:49:00 UTC", "updatedISO": "2023-01-12T11:49:00+00:00", "updateduk": "Jan 12, 2023 at 11:49 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,188.9986", "description": "United States Dollar", "rate_float": 18188.9986}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,198.5817", "description": "British Pound Sterling", "rate_float": 15198.5817}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,718.7402", "description": "Euro", "rate_float": 17718.7402}}}
# {"time": {"updated": "Jan 12, 2023 11:50:00 UTC", "updatedISO": "2023-01-12T11:50:00+00:00", "updateduk": "Jan 12, 2023 at 11:50 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,190.0027", "description": "United States Dollar", "rate_float": 18190.0027}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,199.4207", "description": "British Pound Sterling", "rate_float": 15199.4207}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,719.7183", "description": "Euro", "rate_float": 17719.7183}}}
# {"time": {"updated": "Jan 12, 2023 11:51:00 UTC", "updatedISO": "2023-01-12T11:51:00+00:00", "updateduk": "Jan 12, 2023 at 11:51 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,196.0241", "description": "United States Dollar", "rate_float": 18196.0241}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,204.4521", "description": "British Pound Sterling", "rate_float": 15204.4521}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,725.5841", "description": "Euro", "rate_float": 17725.5841}}}
# {"time": {"updated": "Jan 12, 2023 11:52:00 UTC", "updatedISO": "2023-01-12T11:52:00+00:00", "updateduk": "Jan 12, 2023 at 11:52 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,191.4828", "description": "United States Dollar", "rate_float": 18191.4828}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,200.6575", "description": "British Pound Sterling", "rate_float": 15200.6575}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,721.1602", "description": "Euro", "rate_float": 17721.1602}}}
# {"time": {"updated": "Jan 12, 2023 11:53:00 UTC", "updatedISO": "2023-01-12T11:53:00+00:00", "updateduk": "Jan 12, 2023 at 11:53 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,187.8101", "description": "United States Dollar", "rate_float": 18187.8101}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,197.5886", "description": "British Pound Sterling", "rate_float": 15197.5886}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,717.5825", "description": "Euro", "rate_float": 17717.5825}}}
# {"time": {"updated": "Jan 12, 2023 11:54:00 UTC", "updatedISO": "2023-01-12T11:54:00+00:00", "updateduk": "Jan 12, 2023 at 11:54 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,193.1796", "description": "United States Dollar", "rate_float": 18193.1796}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,202.0753", "description": "British Pound Sterling", "rate_float": 15202.0753}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,722.8131", "description": "Euro", "rate_float": 17722.8131}}}
# {"time": {"updated": "Jan 12, 2023 11:55:00 UTC", "updatedISO": "2023-01-12T11:55:00+00:00", "updateduk": "Jan 12, 2023 at 11:55 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,188.4696", "description": "United States Dollar", "rate_float": 18188.4696}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,198.1397", "description": "British Pound Sterling", "rate_float": 15198.1397}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,718.2249", "description": "Euro", "rate_float": 17718.2249}}}
# {"time": {"updated": "Jan 12, 2023 11:56:00 UTC", "updatedISO": "2023-01-12T11:56:00+00:00", "updateduk": "Jan 12, 2023 at 11:56 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,188.7106", "description": "United States Dollar", "rate_float": 18188.7106}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,198.3411", "description": "British Pound Sterling", "rate_float": 15198.3411}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,718.4597", "description": "Euro", "rate_float": 17718.4597}}}
# {"time": {"updated": "Jan 12, 2023 11:57:00 UTC", "updatedISO": "2023-01-12T11:57:00+00:00", "updateduk": "Jan 12, 2023 at 11:57 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,188.6439", "description": "United States Dollar", "rate_float": 18188.6439}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,198.2853", "description": "British Pound Sterling", "rate_float": 15198.2853}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,718.3947", "description": "Euro", "rate_float": 17718.3947}}}
# {"time": {"updated": "Jan 12, 2023 11:58:00 UTC", "updatedISO": "2023-01-12T11:58:00+00:00", "updateduk": "Jan 12, 2023 at 11:58 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,197.4137", "description": "United States Dollar", "rate_float": 18197.4137}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,205.6133", "description": "British Pound Sterling", "rate_float": 15205.6133}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,726.9378", "description": "Euro", "rate_float": 17726.9378}}}
# {"time": {"updated": "Jan 12, 2023 11:59:00 UTC", "updatedISO": "2023-01-12T11:59:00+00:00", "updateduk": "Jan 12, 2023 at 11:59 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,203.5842", "description": "United States Dollar", "rate_float": 18203.5842}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,210.7693", "description": "British Pound Sterling", "rate_float": 15210.7693}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,732.9487", "description": "Euro", "rate_float": 17732.9487}}}
# {"time": {"updated": "Jan 12, 2023 12:00:00 UTC", "updatedISO": "2023-01-12T12:00:00+00:00", "updateduk": "Jan 12, 2023 at 12:00 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,194.2831", "description": "United States Dollar", "rate_float": 18194.2831}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,202.9974", "description": "British Pound Sterling", "rate_float": 15202.9974}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,723.8881", "description": "Euro", "rate_float": 17723.8881}}}
# {"time": {"updated": "Jan 12, 2023 12:01:00 UTC", "updatedISO": "2023-01-12T12:01:00+00:00", "updateduk": "Jan 12, 2023 at 12:01 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,198.3146", "description": "United States Dollar", "rate_float": 18198.3146}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,206.3661", "description": "British Pound Sterling", "rate_float": 15206.3661}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,727.8154", "description": "Euro", "rate_float": 17727.8154}}}
# {"time": {"updated": "Jan 12, 2023 12:02:00 UTC", "updatedISO": "2023-01-12T12:02:00+00:00", "updateduk": "Jan 12, 2023 at 12:02 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,195.9497", "description": "United States Dollar", "rate_float": 18195.9497}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,204.3900", "description": "British Pound Sterling", "rate_float": 15204.39}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,725.5116", "description": "Euro", "rate_float": 17725.5116}}}
# {"time": {"updated": "Jan 12, 2023 12:03:00 UTC", "updatedISO": "2023-01-12T12:03:00+00:00", "updateduk": "Jan 12, 2023 at 12:03 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,194.1874", "description": "United States Dollar", "rate_float": 18194.1874}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,202.9175", "description": "British Pound Sterling", "rate_float": 15202.9175}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,723.7949", "description": "Euro", "rate_float": 17723.7949}}}
# {"time": {"updated": "Jan 12, 2023 12:04:00 UTC", "updatedISO": "2023-01-12T12:04:00+00:00", "updateduk": "Jan 12, 2023 at 12:04 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,194.9156", "description": "United States Dollar", "rate_float": 18194.9156}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,203.5259", "description": "British Pound Sterling", "rate_float": 15203.5259}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,724.5043", "description": "Euro", "rate_float": 17724.5043}}}
# {"time": {"updated": "Jan 12, 2023 12:05:00 UTC", "updatedISO": "2023-01-12T12:05:00+00:00", "updateduk": "Jan 12, 2023 at 12:05 GMT"}, "disclaimer": "This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org", "chartName": "Bitcoin", "bpi": {"USD": {"code": "USD", "symbol": "&#36;", "rate": "18,194.1593", "description": "United States Dollar", "rate_float": 18194.1593}, "GBP": {"code": "GBP", "symbol": "&pound;", "rate": "15,202.8939", "description": "British Pound Sterling", "rate_float": 15202.8939}, "EUR": {"code": "EUR", "symbol": "&euro;", "rate": "17,723.7675", "description": "Euro", "rate_float": 17723.7675}}}
